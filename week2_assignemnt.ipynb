# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas
df=pandas.read_csv('/content/drive/My Drive/dataset/bitcoin.csv')
df.count()
# Out:
# Date     90
# Open     90
# High     90
# Low      90
# Close    90
# dtype: int64

# %%
df.head(8)
# Out:
#          Date     Open    High      Low    Close
# 0  01/01/2017   991.50  1000.0   969.01   969.01
# 1  02/01/2017  1014.00  1400.0   971.51  1060.00
# 2  03/01/2017  1006.59  1069.5  1006.59  1069.49
# 3  04/01/2017  1070.00  1240.0  1070.00  1210.00
# 4  05/01/2017  1210.00  1212.0   955.08  1068.00
# 5  06/01/2017  1016.01  1080.0   931.00  1001.00
# 6  07/01/2017   942.00  1001.0   860.00   967.50
# 7  08/01/2017   967.50   990.0   901.34   902.01

# %%
import numpy as np
n1= np.array(df['Open'][:90])
n2=np.array(df['Close'][:90])
# print(n1)
# print(n2)
n3= n1-n2

print(n3)

d=np.array(df['Date'][:90])

print(d)
# Out:
# [ 2.2490e+01 -4.6000e+01 -6.2900e+01 -1.4000e+02  1.4200e+02  1.5010e+01
#  -2.5500e+01  6.5490e+01 -3.7500e+01 -1.0000e+00  1.5400e+02 -4.9990e+01
#  -2.1950e+01  2.0000e+00  2.6990e+01  2.4600e+02 -2.4000e+02  4.9000e+01
#  -4.8000e+01 -2.5000e+00 -4.0200e+00 -1.0000e-01 -2.5990e+01 -1.0990e+01
#  -3.5200e+00 -1.7480e+01  3.5000e+00  9.9000e+00  4.0200e+00 -1.2000e+01
#  -4.5010e+01 -1.0900e+01 -1.1100e+01  5.0000e+00 -2.1500e+01 -9.9800e+00
#  -3.9700e+00 -4.5990e+01  1.2500e+01  6.1620e+01  0.0000e+00 -1.8990e+01
#   4.0000e+00  2.4000e+01 -4.7000e+01  1.2000e+01 -2.2000e+01 -4.0000e+01
#   1.0990e+01  1.6500e+01 -2.7500e+01 -7.6800e+01 -2.1000e+01 -3.0990e+01
#   5.2000e-01  1.1000e+01  1.6980e+01 -7.5490e+01  2.6490e+01 -3.9000e+01
#  -4.0470e+01 -3.5990e+01 -1.2000e+01  2.8480e+01 -1.7990e+01  2.8000e+01
#   8.6970e+01 -6.9650e+01  6.2000e+01 -3.2050e+01 -2.6110e+01  1.3860e+01
#  -1.2000e+01 -1.1010e+01  4.2000e+01  5.7000e+01  1.4010e+02 -1.0000e+02
# ...

# %%
import matplotlib.pyplot as plt
#plt.plot(x,y, plot_property)

plt.rcParams['figure.figsize'] = (22,8)

plt.plot(d,n3,'ro-') 
plt.xlabel('Date')
plt.ylabel('Gross Profit or loss')
plt.show()

# %%
dfw=pandas.read_csv('/content/drive/My Drive/dataset/winequality.csv')
dfw.head()
dfw.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
q=np.array(dfw['quality'])
q.sort()
q_unique, q_count = np.unique(q, return_counts=True)
print(q_unique)
print(q_count)
#print(sum(q_count))
# Out:
# [3 4 5 6 7 8]
# [ 10  53 681 638 199  18]

# %%
plt.bar(q_unique,q_count,0.9)
plt.show()
